# %%
import pandas as pd
df = pd.read_csv('/content/Cost_of_Living_Index_by_Country_2024.csv')
df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Switzerland                 101.1        46.5
# 1       2      Bahamas                  85.0        36.7
# 2       3      Iceland                  83.0        39.2
# 3       4    Singapore                  76.7        67.2
# 4       5     Barbados                  76.6        19.0
# ..    ...          ...                   ...         ...
# 116   117   Bangladesh                  22.5         2.4
# 117   118        India                  21.2         5.6
# 118   119        Egypt                  21.0         3.7
# 119   120        Libya                  20.4         4.3
# 120   121     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(df['Country'], df['Cost of Living Index'], marker='o', label='Cost of Living Index')
plt.plot(df['Country'], df['Rent Index'], marker='s', label='Rent Index')
plt.xlabel('Country')
plt.ylabel('Index Value')
plt.title('Cost of Living Index and Rent Index with Markers')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
df_head = df.head(5)
plt.figure(figsize=(12, 6))
plt.plot(df_head['Country'], df_head['Cost of Living Index'], marker='o', label='Cost of Living Index')
plt.plot(df_head['Country'], df_head['Rent Index'], marker='s', label='Rent Index')
plt.xlabel('Country')
plt.ylabel('Index Value')
plt.title('Cost of Living Index and Rent Index (First 5 Rows)')
plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'Rank': [1, 2, 3, 4, 5],
    'Country': ['Switzerland', 'Bahamas', 'Iceland', 'Singapore', 'Barbados'],
    'Cost of Living Index': [101.1, 85.0, 83.0, 76.7, 76.6],
    'Rent Index': [46.5, 36.7, 39.2, 67.2, 19.0],
    'Cost of Living Plus Rent Index': [74.9, 61.8, 62.0, 72.1, 48.9],
    'Groceries Index': [109.1, 81.6, 88.4, 74.6, 80.8],
    'Restaurant Price Index': [97.0, 83.3, 86.8, 50.4, 69.4],
    'Local Purchasing Power Index': [158.7, 54.6, 120.3, 111.1, 43.5]
}
df = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Count of Each Country')
plt.show()
